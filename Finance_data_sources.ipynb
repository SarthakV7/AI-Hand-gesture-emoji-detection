# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakV7/AI-Hand-gesture-emoji-detection/blob/master/Finance_data_sources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas Data reader

# %%
import pandas_datareader.data as pdr
import datetime as dt

# %%
start = dt.datetime(2015, 1, 1)
end = dt.datetime(2017, 1, 1)

# %%
facebook = pdr.get_data_yahoo('FB', start, end)
facebook.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-01-02  78.930000  77.699997  78.580002  78.449997  18177500  78.449997
# 2015-01-05  79.250000  76.860001  77.980003  77.190002  26452200  77.190002
# 2015-01-06  77.589996  75.360001  77.230003  76.150002  27399300  76.150002
# 2015-01-07  77.360001  75.820000  76.760002  76.150002  22045300  76.150002
# 2015-01-08  78.230003  76.080002  76.739998  78.180000  23961000  78.180000

# %% [markdown]
# ### Reading using Quandl

# %%
# !pip install quandl
# !pip install --upgrade plotly

# %%
from datetime import datetime
import pandas as pd
import quandl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set()
# quandl.ApiConfig.api_key = ''

# %%
vix = quandl.get("CHRIS/CBOE_VX1") # S&P 500 volatility
vix.head()
# Out:
#              Open   High    Low  ...  Total Volume  EFP  Prev. Day Open Interest
# Trade Date                       ...
# 2005-06-20  148.3  148.3  148.3  ...           0.0  0.0                      0.0
# 2005-06-21  149.0  149.0  149.0  ...          50.0  0.0                     50.0
# 2005-06-22  148.4  148.4  148.4  ...          10.0  0.0                     60.0
# 2005-06-23  149.8  150.5  149.1  ...          61.0  0.0                    121.0
# 2005-06-24  150.9  152.0  150.5  ...           9.0  0.0                    117.0
#
# [5 rows x 9 columns]

# %%
# Total volume traded
import plotly.express as px

fig = px.line(vix, y='Total Volume')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# OHLC prices
import plotly.graph_objects as go

fig = go.Figure(data=[go.Ohlc(x=vix.index,
                open=vix.Open, high=vix.High,
                low=vix.Low, close=vix.Close)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### San Francisco real estate price data

# %%
sf = quandl.get("FMAC/HPI_SFOCA") # San Francisco real estate price
sf.head()
# Out:
#                 Value
# Date
# 1975-01-31  11.211770
# 1975-02-28  11.223289
# 1975-03-31  11.338424
# 1975-04-30  11.540160
# 1975-05-31  11.699899

# %%
fig = px.line(sf, y='Value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Let's check apple stocks

# %%
df = quandl.get('WIKI/AAPL')
df.head()
# Out:
#              Open   High    Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                             ...
# 1980-12-12  28.75  28.87  28.75  ...  0.422706    0.422706  117258400.0
# 1980-12-15  27.38  27.38  27.25  ...  0.400652    0.400652   43971200.0
# 1980-12-16  25.37  25.37  25.25  ...  0.371246    0.371246   26432000.0
# 1980-12-17  25.87  26.00  25.87  ...  0.380362    0.380362   21610400.0
# 1980-12-18  26.63  26.75  26.63  ...  0.391536    0.391536   18362400.0
#
# [5 rows x 12 columns]

# %%
df.columns[7:11]
# Out:
# Index(['Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close'], dtype='object')

# %%
fig = px.line(df, y=df.columns[7:11])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, y='Split Ratio')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, y='Volume')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
